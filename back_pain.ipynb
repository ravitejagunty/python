# %%
# import libraries for data manipulation
import numpy as np
import pandas as pd

# import libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Importing scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier  # Example for classifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
df = pd.read_csv('/Users/ravs/Downloads/machine-learning-docs/backpain.csv')

# %%
df
# Out:
#      pelvic_incidence  pelvic tilt  lumbar_lordosis_angle  sacral_slope  \
# 0           63.027817    22.552586              39.609117     40.475232
# 1           39.056951    10.060991              25.015378     28.995960
# 2           68.832021    22.218482              50.092194     46.613539
# 3           69.297008    24.652878              44.311238     44.644130
# 4           49.712859     9.652075              28.317406     40.060784
# ..                ...          ...                    ...           ...
# 305         47.903565    13.616688              36.000000     34.286877
# 306         53.936748    20.721496              29.220534     33.215251
# 307         61.446597    22.694968              46.170347     38.751628
# 308         45.252792     8.693157              41.583126     36.559635
# 309         33.841641     5.073991              36.641233     28.767649
#
#      pelvic_radius  degree_spondylolisthesis  pelvic_slope  Direct_tilt  \
# ...

# %%
df_new = pd.get_dummies(df, columns=['Status'])

# %%
df_new
# Out:
#      pelvic_incidence  pelvic tilt  lumbar_lordosis_angle  sacral_slope  \
# 0           63.027817    22.552586              39.609117     40.475232
# 1           39.056951    10.060991              25.015378     28.995960
# 2           68.832021    22.218482              50.092194     46.613539
# 3           69.297008    24.652878              44.311238     44.644130
# 4           49.712859     9.652075              28.317406     40.060784
# ..                ...          ...                    ...           ...
# 305         47.903565    13.616688              36.000000     34.286877
# 306         53.936748    20.721496              29.220534     33.215251
# 307         61.446597    22.694968              46.170347     38.751628
# 308         45.252792     8.693157              41.583126     36.559635
# 309         33.841641     5.073991              36.641233     28.767649
#
#      pelvic_radius  degree_spondylolisthesis  pelvic_slope  Direct_tilt  \
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df_new.corr(),annot=True,cbar=False)
# Out:
# <Axes: >

# %%
df_new['Status_Abnormal'] = df_new['Status_Abnormal'].astype(float)
df_new['Status_Normal'] =df_new['Status_Normal'].astype(float)

# %%
df_new
# Out:
#      pelvic_incidence  pelvic tilt  lumbar_lordosis_angle  sacral_slope  \
# 0           63.027817    22.552586              39.609117     40.475232
# 1           39.056951    10.060991              25.015378     28.995960
# 2           68.832021    22.218482              50.092194     46.613539
# 3           69.297008    24.652878              44.311238     44.644130
# 4           49.712859     9.652075              28.317406     40.060784
# ..                ...          ...                    ...           ...
# 305         47.903565    13.616688              36.000000     34.286877
# 306         53.936748    20.721496              29.220534     33.215251
# 307         61.446597    22.694968              46.170347     38.751628
# 308         45.252792     8.693157              41.583126     36.559635
# 309         33.841641     5.073991              36.641233     28.767649
#
#      pelvic_radius  degree_spondylolisthesis  pelvic_slope  Direct_tilt  \
# ...

# %%
df['Status'] = df['Status'].map({'Abnormal': 1, 'Normal': 0})

# %%
df
# Out:
#      pelvic_incidence  pelvic tilt  lumbar_lordosis_angle  sacral_slope  \
# 0           63.027817    22.552586              39.609117     40.475232
# 1           39.056951    10.060991              25.015378     28.995960
# 2           68.832021    22.218482              50.092194     46.613539
# 3           69.297008    24.652878              44.311238     44.644130
# 4           49.712859     9.652075              28.317406     40.060784
# ..                ...          ...                    ...           ...
# 305         47.903565    13.616688              36.000000     34.286877
# 306         53.936748    20.721496              29.220534     33.215251
# 307         61.446597    22.694968              46.170347     38.751628
# 308         45.252792     8.693157              41.583126     36.559635
# 309         33.841641     5.073991              36.641233     28.767649
#
#      pelvic_radius  degree_spondylolisthesis  pelvic_slope  Direct_tilt  \
# ...

# %%
X = df.drop(columns='Status')
y = df['Status']

# %%
X
# Out:
#      pelvic_incidence  pelvic tilt  lumbar_lordosis_angle  sacral_slope  \
# 0           63.027817    22.552586              39.609117     40.475232
# 1           39.056951    10.060991              25.015378     28.995960
# 2           68.832021    22.218482              50.092194     46.613539
# 3           69.297008    24.652878              44.311238     44.644130
# 4           49.712859     9.652075              28.317406     40.060784
# ..                ...          ...                    ...           ...
# 305         47.903565    13.616688              36.000000     34.286877
# 306         53.936748    20.721496              29.220534     33.215251
# 307         61.446597    22.694968              46.170347     38.751628
# 308         45.252792     8.693157              41.583126     36.559635
# 309         33.841641     5.073991              36.641233     28.767649
#
#      pelvic_radius  degree_spondylolisthesis  pelvic_slope  Direct_tilt  \
# ...

# %%
X_train,X_test,y_train,y_test = train_test_split(
    X,
    y,
    test_size=0.3
)

# %%
y_train.value_counts()[1]/y_train.shape[0]
# Out:
# 0.695852534562212

# %%
model = DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
score = []
for i in range(1, 9):
    model_test = DecisionTreeClassifier(max_depth=i)
    model_test.fit(X_train,y_train)
    y_pred = model_test.predict(X_train)
    recall_train_score = recall_score(y_train,y_pred,average='macro')
    score.append(recall_train_score)
score
# Out:
# [0.828266104756171,
#  0.7107164358819988,
#  0.8253060405378286,
#  0.9010636162954044,
#  0.9360826811157936,
#  0.9649809351796107,
#  0.9749147100140478,
#  0.9891129841460967]

# %%
best_model = DecisionTreeClassifier(max_depth=8)
best_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=8)

# %%
X_train.columns
# Out:
# Index(['pelvic_incidence', 'pelvic tilt', 'lumbar_lordosis_angle',
#        'sacral_slope', 'pelvic_radius', 'degree_spondylolisthesis',
#        'pelvic_slope', 'Direct_tilt', 'thoracic_slope', 'cervical_tilt',
#        'sacrum_angle', 'scoliosis_slope'],
#       dtype='object')

# %%
features = model.feature_importances_

# %%
features
# Out:
# array([0.01905228, 0.04123863, 0.02860316, 0.15449342, 0.09904486,
#        0.42572801, 0.        , 0.04169243, 0.07585688, 0.03629005,
#        0.0720231 , 0.00597719])

# %%
feature_importances = pd.Series(features, index=X_train.columns)

# %%
feature_importances
# Out:
# pelvic_incidence            0.019052
# pelvic tilt                 0.041239
# lumbar_lordosis_angle       0.028603
# sacral_slope                0.154493
# pelvic_radius               0.099045
# degree_spondylolisthesis    0.425728
# pelvic_slope                0.000000
# Direct_tilt                 0.041692
# thoracic_slope              0.075857
# cervical_tilt               0.036290
# sacrum_angle                0.072023
# scoliosis_slope             0.005977
# dtype: float64

# %%
sorted_importances = feature_importances.sort_values(ascending=False)

# %%
sorted_importances
# Out:
# degree_spondylolisthesis    0.425728
# sacral_slope                0.154493
# pelvic_radius               0.099045
# thoracic_slope              0.075857
# sacrum_angle                0.072023
# Direct_tilt                 0.041692
# pelvic tilt                 0.041239
# cervical_tilt               0.036290
# lumbar_lordosis_angle       0.028603
# pelvic_incidence            0.019052
# scoliosis_slope             0.005977
# pelvic_slope                0.000000
# dtype: float64
